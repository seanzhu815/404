# %% [markdown]
# <a href="https://colab.research.google.com/github/seanzhu815/404/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import warnings
import statsmodels
import itertools
from statsmodels.tsa.arima.model import ARIMA

# %%
df=pd.read_excel('assign1.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Lo 10  2019-12-02 00:00:00  2019-12-03 00:00:00  \
# 0    19260701   0.58                -0.13                 0.68
# 1    19260702  -0.53                -0.40                 0.16
# 2    19260706  -0.33                 0.61                -0.38
# 3    19260707   0.28                -0.10                -0.40
# 4    19260708   0.55                -0.90                 0.04
#
#    2019-12-04 00:00:00  2019-12-05 00:00:00  2019-12-06 00:00:00  \
# 0                -0.06                -0.38                -0.07
# 1                 0.10                 0.29                 0.36
# 2                 0.23                 0.68                 0.33
# 3                -0.54                 0.31                 0.17
# 4                 0.23                -0.06                 0.28
#
#    2019-12-07 00:00:00  2019-12-08 00:00:00  2019-12-09 00:00:00  Hi 10  \
# 0                -0.08                -0.06                 0.08   0.18
# ...
